# %% [markdown]
# # Inteligência Artificial (guarda-chuva)
# - Imitação do humano
# - Ajudar o ser humano na produtividade
# - Imita a inteligência humana e seus sentidos
# - Reconhecer padrões e resolver problemas

# %% [markdown]
# # Marchine Learning
# - supervisionado: dados rotulados
# - Não supervisionado: sem dados rotulados

# %% [markdown]
# # Deep Learning
# - A difernça ele possui redes neurais

# %% [markdown]
# # O que você pode fazer:
#
# ## 1- Transformar texto em audio(falar).
# ## 2- Identificar e comparar imagens e objetos(ver).
# ## 3- Aplicar a física (raio cósmicos): modelos que encapsulam funções -velocidade de processamento
#    e entendimento da função.
# ## 4- Engenharia Cível encapsula funções.
# ## 5- Midias sociais -estão te ouvindo para oferecer um produto.
# ## 6- Policia
#     viés: restrições
#     variância: Flexibilidade
#     underfitting
#     overfitting
# ## 7- jogos
# - Supervisionado
# - Não supervisionado
# - Poe reforço
# Xadrez

# %% [markdown]
# # O que vc pode fazer com a IA
# - Inferir espécie de uma flor a partir das medidas desta;
# - DataSet: Iris (código genético e fenótipos)
# - Transormar um digito escrito a mão em texto(string)
# - Recomenda filmes - base dataser de avaliações
# - Analise de sentimentos
# - Detectar objetos
# - Treinar um taxi autônomo

# %% [markdown]
# Métricas
# - Métrica é na régua para medir o desempenho dos nos modelos
# - Função de custo e otimizadores (discerne se a predição é boa ou ruim) - erro do quadrático médio

# %% [markdown]
# # Termiologia

# %% [markdown]
# - Ciência de Dados: campo acadêmico interdisciplina para sugestões de insghts e tomada de decisão.

# %% [markdown]
# - Overffiting : aprendeu demais

# %% [markdown]
# - Underfitting : não aprendeu
# - Viés : restrições impostas na função
# - Variância: flexibilidade da técnica em se adaptar os dados.

# %% [markdown]
# # DataSet

# %%
url = 'https://gist.githubusercontent.com/netj/8836201/raw/6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv'

# %%
! pip install pandas
# Out:
# ...
#   Using cached pandas-2.2.2-cp312-cp312-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-2.2.2-cp312-cp312-win_amd64.whl (11.5 MB)
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/12.6 MB 7.2 MB/s eta 0:00:02
#    -------- ------------------------------- 2.6/12.6 MB 8.0 MB/s eta 0:00:02
#    ------------- -------------------------- 4.2/12.6 MB 7.6 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.5/12.6 MB 7.5 MB/s eta 0:00:01
#    --------------------- ------------------ 6.8/12.6 MB 7.2 MB/s eta 0:00:01
#    -------------------------- ------------- 8.4/12.6 MB 7.2 MB/s eta 0:00:01
#    ------------------------------- -------- 10.0/12.6 MB 7.2 MB/s eta 0:00:01
#    ------------------------------------ --- 11.5/12.6 MB 7.4 MB/s eta 0:00:01
# ...

# %%
import pandas as pd

# %% [markdown]
# Dataset
#
# - inferir referente aos gêneros das flores
# - Medida de pétalas e sépatalas (amostra)

# %%
df = pd.read_csv(url)

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %% [markdown]
# ![f968eec0-3c89-42e6-81e3-4a482fe698f5.jpeg](attachment:f968eec0-3c89-42e6-81e3-4a482fe698f5.jpeg)

# %% [markdown]
# # Inferir especie de uma flor a partir das medidas desta;

# %%
df.head(2)
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa

# %% [markdown]
# # List Comprehension

# %%
df.columns = [s.replace('.','_') for s in df.columns]

# %%
df.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa

# %%
df['variety'].value_counts()
# Out:
# variety
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: count, dtype: int64

# %% [markdown]
# ## obs: estão bem distruidas.
# ## E as medidas?

# %%
df_setosa = df.query('variety == "Setosa"').copy()
df_versicolor = df.query('variety == "Versicolor"').copy()
df_virginica = df.query('variety == "Virginica"').copy()

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'variety'],
#       dtype='object')

# %%
medidas =['sepal_length','sepal_width','petal_length','petal_width']

# %%
! pip  install matplotlib
# Out:
# ...
#   Using cached matplotlib-3.9.2-cp312-cp312-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached contourpy-1.3.0-cp312-cp312-win_amd64.whl.metadata (5.4 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.53.1-cp312-cp312-win_amd64.whl.metadata (165 kB)
# ...
#   Using cached kiwisolver-1.4.7-cp312-cp312-win_amd64.whl.metadata (6.4 kB)
# ...
#   Using cached pillow-10.4.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# ...
#   Using cached pyparsing-3.1.4-py3-none-any.whl.metadata (5.1 kB)
# ...
# Using cached matplotlib-3.9.2-cp312-cp312-win_amd64.whl (7.8 MB)
# Using cached contourpy-1.3.0-cp312-cp312-win_amd64.whl (218 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.53.1-cp312-cp312-win_amd64.whl (2.2 MB)
# Using cached kiwisolver-1.4.7-cp312-cp312-win_amd64.whl (55 kB)
# Using cached pillow-10.4.0-cp312-cp312-win_amd64.whl (2.6 MB)
# Using cached pyparsing-3.1.4-py3-none-any.whl (104 kB)
# ...

# %%
print('Setosa')
df_setosa[medidas].hist()
# Out:
# Setosa
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
print('Setosa')
df_setosa[medidas].hist()
# Out:
# Versicolor
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
print('Virginica')
df_virginica[medidas].hist()
# Out:
# Virginica
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %% [markdown]
# # Filtro de valor especifico de medida

# %%
df.query('petal_length > 5')['variety'].value_counts()
# Out:
# variety
# Virginica     41
# Versicolor     1
# Name: count, dtype: int64

# %% [markdown]
#  Conclusão: praticamente só as plantas da espécie Virginica têm comprimento de pétala maior que cinco
#  - Nenhuma amostra da setosa possui essa medida maior que 5.
#
# - Isso nos diz que a variável "petal_legth" possui um bom preditivo referente a "variety".
# - Quais amostras são de uma espécie e quais não são.

# %% [markdown]
# # A Inteligência artifical possui as seguintes categorias e aplicações:
#
# - Aprendizado por Reforçõ: jogos (tentativa e erro (ambiente))

# %% [markdown]
# -Agente : um jogador
# -Ambiente: problema a ser resolvido
# -ação: é saída do modelo

# %% [markdown]
# ![machine-learning.png](attachment:machine-learning.png)

# %% [markdown]
# ![machine-learning-types.png](attachment:machine-learning-types.png)

# %% [markdown]
# ![supervised-training.png](attachment:supervised-training.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![deep-classification.png](attachment:deep-classification.png)

# %% [markdown]
# Notebook - Introduçã a Inteligência Artificial(Concluído)
